# %% [markdown]
# # Header files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
pokemon_data=pd.read_csv('data/pokemon.csv')

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
combats_data=pd.read_csv('data/combats.csv')

# %%
combats_data.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
tests=pd.read_csv('data/tests.csv')

# %%
tests.head()
# Out:
#    First_pokemon  Second_pokemon
# 0            129             117
# 1            660             211
# 2            706             115
# 3            195             618
# 4             27             656

# %%
pokemon_data.shape
# Out:
# (800, 12)

# %%
#Checking null values in the data

# %%
pokemon_null=pokemon_data.isnull().sum()
pokemon_null[pokemon_null>0].sort_values(ascending=True)
# Out:
# Name        1
# Type 2    386
# dtype: int64

# %%
pokemon_data['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon_data['Speed'].plot(kind='hist',bins=50)

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon_data.Legendary.value_counts().plot(kind='bar')

# %%
pokemon_data.Generation.value_counts().plot(kind='bar')

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(pokemon_data.corr(),annot=True,linewidth=0.5,fmt='.2f',ax=ax)

# %%
pokemon_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon_data.Speed.plot(kind='line',color='g',alpha=0.5,linewidth=1,linestyle=':')
pokemon_data.Defense.plot(kind='line',color='r',alpha=0.5,linewidth=1,linestyle='-.')
plt.legend()
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
# Out:
# Text(0.5,1,'Line Plot')

# %%
pokemon_data.plot(kind='scatter',x='Attack',y='Defense',alpha=0.5,color='r')
plt.title('Attack vs Defense')
# Out:
# Text(0.5,1,'Attack vs Defense')

# %%
pokemon_data.Speed.plot(kind='hist',bins=50,color='g',figsize=(15,15))

# %%
plt.clf()

# %%
dicti={'spain':'madrid','usa':'vegas'}
print(dicti.keys())
print(dicti.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
dicti['spain']='barca'
print(dicti)
dicti['france']='paris'
print(dicti)
del dicti['spain']
print(dicti)

print('france' in dicti)
dicti.clear()
print(dicti)
# Out:
# {'spain': 'barca', 'usa': 'vegas'}
# {'spain': 'barca', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
print(dicti)
# Out:
# {}

# %%
seriers=pokemon_data['Defense']
print(seriers)
# Out:
# 0       49
# 1       63
# 2       83
# 3      123
# 4       43
# 5       58
# 6       78
# 7      111
# 8       78
# 9       65
# 10      80
# 11     100
# 12     120
# 13      35
# 14      55
# 15      50
# 16      30
# 17      50
# 18      40
# 19      40
# 20      40
# 21      55
# 22      75
# 23      80
# 24      35
# 25      60
# 26      30
# 27      65
# 28      44
# 29      69
#       ...
# 770     65
# 771     75
# 772     57
# 773    150
# 774     35
# 775     53
# 776     70
# 777     91
# 778     48
# 779     76
# 780     70
# 781     70
# 782     70
# 783     70
# 784    122
# 785    122
# 786    122
# 787    122
# 788     85
# 789    184
# 790     35
# 791     80
# 792     95
# 793     95
# 794    121
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64

# %%
dataframe=pokemon_data[['Defense','Attack']]

# %%
print(dataframe)
# Out:
#      Defense  Attack
# 0         49      49
# 1         63      62
# 2         83      82
# 3        123     100
# 4         43      52
# 5         58      64
# 6         78      84
# 7        111     130
# 8         78     104
# 9         65      48
# 10        80      63
# 11       100      83
# 12       120     103
# 13        35      30
# 14        55      20
# 15        50      45
# 16        30      35
# 17        50      25
# 18        40      90
# 19        40     150
# 20        40      45
# 21        55      60
# 22        75      80
# 23        80      80
# 24        35      56
# 25        60      81
# 26        30      60
# 27        65      90
# 28        44      60
# 29        69      85
# ..       ...     ...
# 770       65      65
# 771       75      92
# 772       57      58
# 773      150      50
# 774       35      50
# 775       53      75
# 776       70     100
# 777       91      80
# 778       48      70
# 779       76     110
# 780       70      66
# ...

# %%
print(3>2)
print(3!=2)

print(True)
print(False or True)
# Out:
# True
# True
# True
# True

# %%
x=pokemon_data['Defense']>200
pokemon_data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
pokemon_data[np.logical_and(pokemon_data['Defense']>200,pokemon_data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
pokemon_data[(pokemon_data['Defense']>200) & (pokemon_data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
i=0
while i!=5:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lis=[1,2,3,4,5]
for i in lis:
    print (i)
print(' ')
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for index,value in enumerate(lis):
    print(index, ": ",value)
# Out:
# 0 :  1
# 1 :  2
# 2 :  3
# 3 :  4
# 4 :  5

# %%
dictionary={'spain':'madrid','france':'paris'}

for key,value in dictionary.items():
    print(key, ": ",value)
# Out:
# spain :  madrid
# france :  paris

# %%
for index,value in pokemon_data[['Attack']][0:1].iterrows():
    print(index, ", ",value)
# Out:
# 0 ,  Attack    49
# Name: 0, dtype: int64

# %%
def square():
    def add():
        x=2
        y=3
        z=x+y
        return z
    return add()**2
print(square())
# Out:
# 25

# %%
def f(a,b=1,c=2):
    z=a+b+c
    return z
print(f(5))

print(f(5,5,5))
# Out:
# 8
# 15

# %% [markdown]
# # 3.CLEANING DATA

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon_data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
pokemon_data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon_data.shape
# Out:
# (800, 12)

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# # EXPLOTARY DATA ANALYSIS

# %%
print(pokemon_data['Type 1'].value_counts(dropna=False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon_data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemon_data.boxplot(column='Attack',by='Legendary')

# %%
data_new=pokemon_data[0:5]

# %%
data_new.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
melted=pd.melt(data_new,id_vars='Name',value_vars=['Attack','Defense'])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted.pivot(index='Name',columns='variable',values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
#concat Data

# %%
data1=pokemon_data.head()
data2=pokemon_data.tail()
con_data=pd.concat([data1,data2],axis=0,join_axes=None)
con_data
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# ...

# %%
data1=pokemon_data['Attack'].head()
data2=pokemon_data['Defense'].head()
con_data=pd.concat([data1,data2],axis=1)
con_data
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
#Data types

# %%
pokemon_data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon_data['Type 1']=pokemon_data['Type 1'].astype('category')
pokemon_data['Speed']=pokemon_data['Speed'].astype('float')

# %%
pokemon_data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
#missing Data and Testing with Assert

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null float64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
pokemon_data['Type 2'].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ghost        14
# Water        14
# Rock         14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
sample_data=pokemon_data
sample_data['Type 2'].dropna(inplace=True)

# %%
sample_data['Type 2'].value_counts(dropna=False)
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ice         14
# Ghost       14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
assert 1==1

# %%
assert pokemon_data['Type 2'].notnull().all()

# %%
pokemon_data['Type 2'].fillna('empty',inplace=True)

# %%
assert pokemon_data['Type 2'].notnull().all()

# %%
#Pandas Foundation

# %%
country=["Spain","France"]
population=["11","12"]

list_label=["Country","Population"]
list_col=[country,population]

zipped=list(zip(list_label,list_col))
data_dict=dict(zipped)

# %%
df=pd.DataFrame(data_dict)
df
# Out:
#   Country Population
# 0   Spain         11
# 1  France         12

# %%
df["capital"]=["madrid","paris"]
df
# Out:
#   Country Population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
#Plotting

# %%
data1=pokemon_data.loc[:,["Attack","Defense","Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000007BD339E550>,
# ...
#       dtype=object)

# %%
data1.plot(kind='scatter',x='Attack',y='Defense')

# %%
data1.plot(kind='hist',y="Defense",bins=50)

# %%
f,ax=plt.subplots(nrows=2,ncols=1)

data1.plot(kind='hist',y='Defense',bins=50,ax=ax[0])
data1.plot(kind='hist',y='Attack',bins=50,ax=ax[1])

# %%
pokemon_data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
time_list=["1992,03,08","1992-04-12"]
print(type(time_list))
datetime=pd.to_datetime(time_list)
print(type(datetime))
# Out:
# <class 'list'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data2=pokemon_data.head()

date_list=["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]

date=pd.to_datetime(date_list)
data2["date"]=date

data2=data2.set_index("date")

data2
# Out:
# C:\Users\ARJUN_PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# ...

# %%
print(data2.loc["1992-02-10"])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1992-02-10 00:00:00, dtype: object

# %%
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
data2.resample("A").mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample("M").mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#                    #           Name Type 1  Type 2    HP  Attack     Defense  \
# date
# 1992-01-31  1.000000      Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1992-02-29  2.000000        Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 1992-03-31  3.000000       Venusaur  Grass  Poison  80.0    82.0   83.000000
# 1992-04-30  3.083333            NaN    NaN     NaN  80.0    83.5   86.333333
# 1992-05-31  3.166667            NaN    NaN     NaN  80.0    85.0   89.666667
# 1992-06-30  3.250000            NaN    NaN     NaN  80.0    86.5   93.000000
# 1992-07-31  3.333333            NaN    NaN     NaN  80.0    88.0   96.333333
# 1992-08-31  3.416667            NaN    NaN     NaN  80.0    89.5   99.666667
# 1992-09-30  3.500000            NaN    NaN     NaN  80.0    91.0  103.000000
# 1992-10-31  3.583333            NaN    NaN     NaN  80.0    92.5  106.333333
# 1992-11-30  3.666667            NaN    NaN     NaN  80.0    94.0  109.666667
# ...

# %%
#Manipulating Data

# %%
temp_data=pokemon_data

# %%
temp_data=temp_data.set_index("#")
temp_data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65   45.0
# 2        Ivysaur  Grass  Poison  60      62       63       80       80   60.0
# 3       Venusaur  Grass  Poison  80      82       83      100      100   80.0
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120   80.0
# 5     Charmander   Fire     NaN  39      52       43       60       50   65.0
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
temp_data["HP"][1]
# Out:
# 45

# %%
temp_data.HP[1]
# Out:
# 45

# %%
temp_data.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
temp_data[["Attack","Defense"]]
# Out:
#      Attack  Defense
# #
# 1        49       49
# 2        62       63
# 3        82       83
# 4       100      123
# 5        52       43
# 6        64       58
# 7        84       78
# 8       130      111
# 9       104       78
# 10       48       65
# 11       63       80
# 12       83      100
# 13      103      120
# 14       30       35
# 15       20       55
# 16       45       50
# 17       35       30
# 18       25       50
# 19       90       40
# 20      150       40
# 21       45       40
# 22       60       55
# 23       80       75
# 24       80       80
# 25       56       35
# 26       81       60
# 27       60       30
# 28       90       65
# 29       60       44
# 30       85       69
# ..      ...      ...
# 771      65       65
# 772      92       75
# 773      58       57
# 774      50      150
# 775      50       35
# 776      75       53
# 777     100       70
# 778      80       91
# 779      70       48
# 780     110       76
# 781      66       70
# ...

# %%
#Slicing Data Frame

# %%
print(type(pokemon_data["Attack"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(pokemon_data[["Attack","Defense"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pokemon_data.loc[1:10,"Attack":"Defense"]
# Out:
#     Attack  Defense
# 1       62       63
# 2       82       83
# 3      100      123
# 4       52       43
# 5       64       58
# 6       84       78
# 7      130      111
# 8      104       78
# 9       48       65
# 10      63       80

# %%
pokemon_data.loc[10:1:-1,"Attack":"Defense"]
# Out:
#     Attack  Defense
# 10      63       80
# 9       48       65
# 8      104       78
# 7      130      111
# 6       84       78
# 5       64       58
# 4       52       43
# 3      100      123
# 2       82       83
# 1       62       63

# %%
pokemon_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# 2   80.0           1      False
# 3   80.0           1      False
# 4   65.0           1      False

# %%
pokemon_data.loc[1:10,"HP":]
# Out:
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1   60      62       63       80       80   60.0           1      False
# 2   80      82       83      100      100   80.0           1      False
# 3   80     100      123      122      120   80.0           1      False
# 4   39      52       43       60       50   65.0           1      False
# 5   58      64       58       80       65   80.0           1      False
# 6   78      84       78      109       85  100.0           1      False
# 7   78     130      111      130       85  100.0           1      False
# 8   78     104       78      159      115  100.0           1      False
# 9   44      48       65       50       64   43.0           1      False
# 10  59      63       80       65       80   58.0           1      False

# %%
#Filtering Data Frames

# %%
boolean=pokemon_data.HP>200
pokemon_data[boolean]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal    NaN  250       5        5       35      105
# 261  262  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121   50.0           1      False
# 261   55.0           2      False

# %%
first_filter=pokemon_data.HP>150
second_filter=pokemon_data.Speed>35
pokemon_data[first_filter & second_filter]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122    Chansey  Normal    NaN  250       5        5       35      105
# 261  262    Blissey  Normal    NaN  255      10       10       75      135
# 351  352    Wailord   Water    NaN  170      90       45       90       45
# 655  656  Alomomola   Water    NaN  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 121   50.0           1      False
# 261   55.0           2      False
# 351   60.0           3      False
# 655   65.0           5      False

# %%
pokemon_data.HP[pokemon_data.Speed<15]
# Out:
# 230     20
# 359     45
# 486     50
# 495    135
# 658     44
# Name: HP, dtype: int64

# %%
#Transform Data

# %%
def div(n):
    return n/2
temp_data=pokemon_data
temp_data.HP.apply(div)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
# 5      29.0
# 6      39.0
# 7      39.0
# 8      39.0
# 9      22.0
# 10     29.5
# 11     39.5
# 12     39.5
# 13     22.5
# 14     25.0
# 15     30.0
# 16     20.0
# 17     22.5
# 18     32.5
# 19     32.5
# 20     20.0
# 21     31.5
# 22     41.5
# 23     41.5
# 24     15.0
# 25     27.5
# 26     20.0
# 27     32.5
# 28     17.5
# 29     30.0
#        ...
# 770    47.5
# 771    39.0
# 772    33.5
# 773    25.0
# 774    22.5
# 775    34.0
# 776    45.0
# 777    28.5
# 778    21.5
# 779    42.5
# 780    24.5
# 781    22.0
# 782    27.0
# 783    29.5
# 784    32.5
# 785    27.5
# 786    37.5
# 787    42.5
# 788    27.5
# 789    47.5
# 790    20.0
# 791    42.5
# 792    63.0
# 793    63.0
# 794    54.0
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
temp_data["total_power"]=temp_data.Attack+temp_data.Defense

temp_data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  total_power
# 0   45.0           1      False           98
# 1   60.0           1      False          125
# 2   80.0           1      False          165
# 3   80.0           1      False          223
# 4   65.0           1      False           95

# %%
#index objects and labeled Data

# %%
temp_data=temp_data.set_index("#")
print(temp_data.index.name)
# Out:
# #

# %%
temp_data.index.name="ID"

# %%
temp_data.head()
# Out:
#              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# ID
# 1       Bulbasaur  Grass  Poison  45      49       49       65       65
# 2         Ivysaur  Grass  Poison  60      62       63       80       80
# 3        Venusaur  Grass  Poison  80      82       83      100      100
# 4   Mega Venusaur  Grass  Poison  80     100      123      122      120
# 5      Charmander   Fire     NaN  39      52       43       60       50
#
#     Speed  Generation  Legendary  total_power
# ID
# 1    45.0           1      False           98
# 2    60.0           1      False          125
# 3    80.0           1      False          165
# 4    80.0           1      False          223
# 5    65.0           1      False           95

# %%
data1=temp_data
data1.shape
# Out:
# (800, 12)

# %%
data1.head()
# Out:
#              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# ID
# 1       Bulbasaur  Grass  Poison  45      49       49       65       65
# 2         Ivysaur  Grass  Poison  60      62       63       80       80
# 3        Venusaur  Grass  Poison  80      82       83      100      100
# 4   Mega Venusaur  Grass  Poison  80     100      123      122      120
# 5      Charmander   Fire     NaN  39      52       43       60       50
#
#     Speed  Generation  Legendary  total_power
# ID
# 1    45.0           1      False           98
# 2    60.0           1      False          125
# 3    80.0           1      False          165
# 4    80.0           1      False          223
# 5    65.0           1      False           95

# %%
data1.index=range(100,900,1)

data1.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100   45.0           1      False           98
# 101   60.0           1      False          125
# 102   80.0           1      False          165
# 103   80.0           1      False          223
# 104   65.0           1      False           95

# %%
#Hierarchical Indexing

# %%
pokemon_data=pd.read_csv('data/pokemon.csv')

# %%
pokemon_data.shape
# Out:
# (800, 12)

# %%
data1=pokemon_data.set_index(["Type 1","Type 2"])
data1.head(100)
# Out:
#                     #              Name   HP  Attack  Defense  Sp. Atk  \
# Type 1   Type 2
# Grass    Poison     1         Bulbasaur   45      49       49       65
#          Poison     2           Ivysaur   60      62       63       80
#          Poison     3          Venusaur   80      82       83      100
#          Poison     4     Mega Venusaur   80     100      123      122
# Fire     NaN        5        Charmander   39      52       43       60
#          NaN        6        Charmeleon   58      64       58       80
#          Flying     7         Charizard   78      84       78      109
#          Dragon     8  Mega Charizard X   78     130      111      130
#          Flying     9  Mega Charizard Y   78     104       78      159
# Water    NaN       10          Squirtle   44      48       65       50
#          NaN       11         Wartortle   59      63       80       65
#          NaN       12         Blastoise   79      83      100       85
# ...

# %%
#Pivoting Data Frames

# %%
dic={"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df=pd.DataFrame(dic)

df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
df.pivot(index='treatment',columns='gender',values='response')
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
#Stacking and unstacking Dataframe
df1=df.set_index(['treatment','gender'])
df1
# Out:
#                   age  response
# treatment gender
# A         F        15        10
#           M         4        45
# B         F        72         5
#           M        65         9

# %%
df1.unstack(level=0)
# Out:
#           age     response
# treatment   A   B        A  B
# gender
# F          15  72       10  5
# M           4  65       45  9

# %%
df2=df1.swaplevel(0,1)

# %%
df2.unstack(level=1)
# Out:
#           age     response
# treatment   A   B        A  B
# gender
# F          15  72       10  5
# M           4  65       45  9

# %%
#Melting of DataFrame

# %%
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
pd.melt(df,id_vars='treatment',value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
#Catergory and Groupby
